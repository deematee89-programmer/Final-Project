# %% [markdown]
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # Welcome to my "phase 3" <3!!

# %% [markdown]
# ---
#
#
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %% [markdown]
# # 1.Import Phase "1 And 2" Files

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ac0a2f6e-379e-4a05-9263-90366208c0be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac0a2f6e-379e-4a05-9263-90366208c0be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dc7a29fe-47b6-4360-87e6-8b0d25eef1d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc7a29fe-47b6-4360-87e6-8b0d25eef1d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ####================================================================================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
import kagglehub
path = kagglehub.dataset_download("dansbecker/melbourne-housing-snapshot")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'melbourne-housing-snapshot' dataset.
# Path to dataset files: /kaggle/input/melbourne-housing-snapshot

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
def load_ds(path):
  df = pd.read_csv(path)
  print(df.head())
  return df

path = "/content/melb_data.csv"
df = load_ds(path)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 2.Histogram \ Kde

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
#MY CODE:

f1st_col=df["Price"].hist(bins=30)

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
#MY CODE:

S2nd_col=df["Rooms"].hist(bins=10)

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
#MY CODE:
t3rd_col=df["YearBuilt"].hist(bins=30)

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
#MY CODE:
sns.kdeplot(df["Bedroom2"],fill=True)
# Out:
# <Axes: xlabel='Bedroom2', ylabel='Density'>

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 3.Grouped Boxplots

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
#MY CODE:

sns.boxplot(x="Type",y="Price",data=df)
plt.title("Price by Type")
plt.show()

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 4.Correlation Heatmap

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
corr=df.corr(numeric_only=True)
top_corr=corr["Price"].abs().sort_values(ascending=False).head(10)
plt.figure(figsize=(6,4))
sns.heatmap(df[top_corr.index].corr(),annot=True,cmap=("pink"))
plt.title("Top Corr Features With Price")
plt.show()

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 5.Scatter plot

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
plt.figure()
sns.scatterplot(x="BuildingArea",y="Price",hue="YearBuilt",data=df)
plt.title("Building Area vs Price")
plt.show()

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 6.Groupby Summary

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
#MY CODE:

group=df.groupby("Regionname")["Price"].mean().sort_values()

print(group)
# Out:
# Regionname
# Western Victoria              3.975234e+05
# Northern Victoria             5.948293e+05
# Eastern Victoria              6.999808e+05
# Western Metropolitan          8.664205e+05
# Northern Metropolitan         8.981711e+05
# South-Eastern Metropolitan    9.229438e+05
# Eastern Metropolitan          1.104080e+06
# Southern Metropolitan         1.372963e+06
# Name: Price, dtype: float64
