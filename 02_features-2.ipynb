# %% [markdown]
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # Welcome to my "Phase 2" <3 !!

# %% [markdown]
# ---
#
#
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %% [markdown]
# # *Catlouge of my **phase 2**:*
#
# 1.   Import phase 1 file
# 2.   One Hot Encode
# 3.   Ordinal incoding
# 4.   Scaling
# 5.   Domain Featurs
# 6.   Interaction Feature
# 7.   Log Transform (log1p)
# 8.   Binning
# 9.   Remove Redundant Features

# %% [markdown]
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 1.Import Phase1 File

# %% [markdown]
# ---
#
#
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %% [markdown]
# ## First i will:
#
# *   import phase 1
# *   import the librires i will use
# *   Donlowd the dataset

# %% [markdown]
# ---
#
#
# ####<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7f97e6f9-4f68-4af6-b4ce-4bf030de02a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f97e6f9-4f68-4af6-b4ce-4bf030de02a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ####================================================================================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
import kagglehub
path = kagglehub.dataset_download("dansbecker/melbourne-housing-snapshot")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'melbourne-housing-snapshot' dataset.
# Path to dataset files: /kaggle/input/melbourne-housing-snapshot

# %% [markdown]
# ####-------------------------------------------------------------------------------------------------------------------------

# %%
def load_ds(path):
  df = pd.read_csv(path)
  print(df.head())
  return df

path = "/content/melb_data.csv"
df = load_ds(path)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 2.One Hot Encoding

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %% [markdown]
# #
#
# *   Here i will do one hot incoding using pandas "get dummies"

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:
onehot_encode=pd.get_dummies(df,columns=["Address","Type"])

#Print reasults:
print("="*70)
print("One Hot Encoding:")
print("="*70)
print(onehot_encode)
print("="*70)
# Out:
#               Suburb  Rooms      Price Method   SellerG        Date  Distance  \
# 0         Abbotsford      2  1480000.0      S    Biggin   3/12/2016       2.5
# 1         Abbotsford      2  1035000.0      S    Biggin   4/02/2016       2.5
# 2         Abbotsford      3  1465000.0     SP    Biggin   4/03/2017       2.5
# 3         Abbotsford      3   850000.0     PI    Biggin   4/03/2017       2.5
# 4         Abbotsford      4  1600000.0     VB    Nelson   4/06/2016       2.5
# ...              ...    ...        ...    ...       ...         ...       ...
# 13575  Wheelers Hill      4  1245000.0      S     Barry  26/08/2017      16.7
# 13576   Williamstown      3  1031000.0     SP  Williams  26/08/2017       6.8
# 13577   Williamstown      3  1170000.0      S     Raine  26/08/2017       6.8
# 13578   Williamstown      4  2500000.0     PI   Sweeney  26/08/2017       6.8
# 13579     Yarraville      4  1285000.0     SP   Village  26/08/2017       6.3
#
# ...

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# #3.Ordinal Encoding

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# #
#
#
# *   there's no valid columns to apply ordinal encoding on it.

# %% [markdown]
# ####===============================================================================================

# %% [markdown]
# # Pass

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 4.Scaling

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# #
#
#
# *  here i will scale numric columns using "Standard Scaler"

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:

X= df.select_dtypes(include=["int64","float64"]).drop("Price",axis=1)
Y= df["Price"]

X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=42)


num_cols=["Rooms","BuildingArea"]

scaler=StandardScaler()

X_train[num_cols]=scaler.fit_transform(X_train[num_cols])
X_test[num_cols]=scaler.transform(X_test[num_cols])

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 5.Domain Features

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# #
# * Created meaningful features
# using ratios (safe division)

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:


df["price_per_area"]=df["Price"] /(df["BuildingArea"]+1)

df["rooms_per_house"]=df["Rooms"]/(df["Car"]+1)

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 6.Interaction Feature

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# #
#
# *  Created a new feature by multiplying two related columns

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:

df["rooms_x_area"] =df["Rooms"] *df["BuildingArea"]

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 7.Log Transform (log1p)

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# #
#
# *  Applied log transformation to reduce skewness

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:

df["Price"].hist()
plt.title("Before log transform")
plt.show()

df["Price_log"]=np.log1p(df["Price"])

df["Price_log"].hist()
plt.title("After log transform")
plt.show()

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 8.Binning

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# #
#
#
# *  Converted numerical column into categories (groups)

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:

def age_group(year):
  if year > 2000:
    return "New"
  elif year > 1980:
    return "Recent"
  else:
    return "Old"

df["AgeGroup"] =df["YearBuilt"].apply(age_group)

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# # 9.Remove Redundant Features

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# #
#
# *   Removed highly correlated features to reduce redundancy

# %% [markdown]
# ####===============================================================================================

# %%
#MY CODE:

def drop_corr_featurs(df,threshold=0.95):
  corr_matrix=df.corr().abs()
  upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
  dropping=[col for col in upper.columns if any(upper[col]>threshold)]
  return df.drop(columns=dropping),dropping

train ,dropped_columns=drop_corr_featurs(train ,threshold=0.95)
test=test.drop(columns=dropped_columns)

print("Dropped Columns:")
print(dropped_columns)

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---

# %% [markdown]
# ## The End of phase2 ***Thank you so much <3!!***

# %% [markdown]
# ---
#
#
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
#
# ---

# %% [markdown]
# # Go To Phase  -> 3 !! <3

# %% [markdown]
# #<><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# ---
